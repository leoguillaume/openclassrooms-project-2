# %%
import pandas as pd
import numpy as np
import os
pd.set_option("display.max_columns", 500)
pd.set_option("max_colwidth", 500)
pd.set_option('display.max_rows', 500)

# %%
ls ../data/Projet+Python_Dataset_Edstats_csv/
# Out:
# EdStatsCountry-Series.csv  EdStatsFootNote.csv
# EdStatsCountry.csv         EdStatsSeries.csv
# EdStatsData.csv

# %%
pwd
# Out:
# '/Users/leoguillaume/Documents/openclassrooms-projects/openclassrooms-project-2/src'

# %%
filepath = '/Users/leoguillaume/Documents/openclassrooms-projects/openclassrooms-project-2/data/Projet+Python_Dataset_Edstats_csv/'

# %%
csv_list = os.listdir(filepath)

# %%
for csv in csv_list:
    locals()[csv[:-4]] = pd.read_csv(os.path.join(filepath,csv))

# %%
for csv in csv_list:
    print(csv+'\n'+40*'-')
    locals()[csv[:-4]].info()
    print('\n')
# Out:
# EdStatsCountry.csv
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
# ...

# %%
EdStatsCountrySeries = locals()['EdStatsCountry-Series']

# %%
# Out:
#        CountryCode      SeriesCode    Year  \
# 0              ABW  SE.PRE.ENRL.FE  YR2001
# 1              ABW  SE.TER.TCHR.FE  YR2005
# 2              ABW  SE.PRE.TCHR.FE  YR2000
# 3              ABW  SE.SEC.ENRL.GC  YR2004
# 4              ABW     SE.PRE.TCHR  YR2006
# ...            ...             ...     ...
# 643633         ZWE     SH.DYN.MORT  YR2007
# 643634         ZWE     SH.DYN.MORT  YR2014
# 643635         ZWE     SH.DYN.MORT  YR2015
# 643636         ZWE     SH.DYN.MORT  YR2017
# 643637         ZWE     SP.POP.GROW  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 0                          Country estimation.         NaN
# 1                          Country estimation.         NaN
# 2                          Country estimation.         NaN
# 3                          Country estimation.         NaN
# 4                          Country estimation.         NaN
# ...                                        ...         ...
# ...

# %%
EdStatsFootNote.loc[(EdStatsFootNote['CountryCode'] == 'FRA') & (EdStatsFootNote['SeriesCode'] == 'SE.SEC.ENRL.TC.ZS')].sort_values('Year')
# Out:
#        CountryCode         SeriesCode    Year   DESCRIPTION  Unnamed: 4
# 198622         FRA  SE.SEC.ENRL.TC.ZS  YR1971  Country Data         NaN
# 198623         FRA  SE.SEC.ENRL.TC.ZS  YR1972  Country Data         NaN
# 198624         FRA  SE.SEC.ENRL.TC.ZS  YR1973  Country Data         NaN
# 198625         FRA  SE.SEC.ENRL.TC.ZS  YR1974  Country Data         NaN
# 198626         FRA  SE.SEC.ENRL.TC.ZS  YR1977  Country Data         NaN
# 198627         FRA  SE.SEC.ENRL.TC.ZS  YR1978  Country Data         NaN
# 198628         FRA  SE.SEC.ENRL.TC.ZS  YR1979  Country Data         NaN
# 198629         FRA  SE.SEC.ENRL.TC.ZS  YR1980  Country Data         NaN
# 198630         FRA  SE.SEC.ENRL.TC.ZS  YR1989  Country Data         NaN
# 198631         FRA  SE.SEC.ENRL.TC.ZS  YR1990  Country Data         NaN
# 198632         FRA  SE.SEC.ENRL.TC.ZS  YR1991  Country Data         NaN
# 198633         FRA  SE.SEC.ENRL.TC.ZS  YR1992  Country Data         NaN
# ...

# %%
EdStatsData.loc[(EdStatsData['Country Code'] == 'FRA') & (EdStatsData['Indicator Code'] == 'SE.SEC.ENRL.TC.ZS')]
# Out:
#        Country Name Country Code  \
# 339732       France          FRA
#
#                                            Indicator Name     Indicator Code  \
# 339732  Pupil-teacher ratio in secondary education (he...  SE.SEC.ENRL.TC.ZS
#
#         1970      1971      1972      1973      1974  1975  1976     1977  \
# 339732   NaN  15.80167  15.49716  15.56402  15.43252   NaN   NaN  14.1608
#
#             1978      1979     1980  1981  1982  1983  1984  1985  1986  1987  \
# 339732  14.01968  13.86533  13.7283   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1988      1989      1990      1991      1992      1993      1994  \
# 339732   NaN  13.01208  12.43865  12.50841  12.49112  12.14632  12.78847
#
#             1995      1996      1997  1998      1999      2000      2001  \
# 339732  12.67498  12.49607  12.36769   NaN  12.02547  11.79826  11.60577
#
#             2002      2003      2004      2005      2006      2007      2008  \
# ...

# %% [markdown]
# #### Table contents
#
# EdStatsSeries : informations about indicators (descriptions)
#
# EdStatsCountry : country statistics > incomes group
#
# EdStatsCountrySeries : sources of StatSeries >> useless
#
# EdStatsData : country education statistics >> removes all year > 2014
#
# EdStatsFootNote : year of country indicator of EdStatsData are present

# %% [markdown]
# ## Zoom EdStatsData

# %%
EdStatsCountry : country statistics > incomes group

# %%
EdStatsSeries.Topic.value_counts()
# Out:
# Learning Outcomes                                                                               1046
# Attainment                                                                                       733
# Education Equality                                                                               426
# Secondary                                                                                        256
# Primary                                                                                          248
# Population                                                                                       213
# Tertiary                                                                                         158
# Teachers                                                                                         137
# Expenditures                                                                                      93
# ...

# %% [markdown]
# https://en.wikipedia.org/wiki/Secondary_education#By_country
# https://en.wikipedia.org/wiki/Tertiary_education
#
# Focus on upper secondary and tertiary education

# %%
EdStatsSeries[EdStatsSeries.Topic == 'Secondary'][['Series Code', 'Long definition']].sort_values('Series Code')
# Out:
#                        Series Code  \
# 2218             SE.ENR.PRSC.FM.ZS
# 2219             SE.ENR.SECO.FM.ZS
# 2287                   SE.SEC.AGES
# 2288          SE.SEC.CMPT.LO.FE.ZS
# 2289          SE.SEC.CMPT.LO.MA.ZS
# 2290             SE.SEC.CMPT.LO.ZS
# 2291                   SE.SEC.DURS
# 2292               SE.SEC.DURS.LO
# 2293                SE.SEC.DURS.UP
# 2294                   SE.SEC.ENRL
# 2295                SE.SEC.ENRL.FE
# 2296          SE.SEC.ENRL.FE.VO.ZS
# 2297             SE.SEC.ENRL.FE.ZS
# 2298                SE.SEC.ENRL.GC
# 2299             SE.SEC.ENRL.GC.FE
# 2300          SE.SEC.ENRL.GC.FE.ZS
# 2301          SE.SEC.ENRL.MA.VO.ZS
# 2303                SE.SEC.ENRL.VO
# 2304             SE.SEC.ENRL.VO.FE
# 2305          SE.SEC.ENRL.VO.FE.ZS
# 2306             SE.SEC.ENRL.VO.ZS
# 2307                   SE.SEC.ENRR
# 2308                SE.SEC.ENRR.FE
# 2309                SE.SEC.ENRR.LO
# 2310             SE.SEC.ENRR.LO.FE
# ...

# %%
import re

# %%
if re.search('upper secondary', ' secondary  percentage of upper secondary female population upper secondary age 15-19 with no education'):
    print('f')
# Out:
# f

# %%
EdStatsSeries.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
EdStatsSeries.dropna(subset = ['Short definition'])
# Out:
#                       Series Code         Topic  \
# 0             BAR.NOED.1519.FE.ZS    Attainment
# 1                BAR.NOED.1519.ZS    Attainment
# 2             BAR.NOED.15UP.FE.ZS    Attainment
# 3                BAR.NOED.15UP.ZS    Attainment
# 4             BAR.NOED.2024.FE.ZS    Attainment
# ...                           ...           ...
# 3647  UIS.XUNIT.PPPCONST.23.FSGOV  Expenditures
# 3649   UIS.XUNIT.PPPCONST.4.FSGOV  Expenditures
# 3650  UIS.XUNIT.PPPCONST.56.FSGOV  Expenditures
# 3663  XGDP.23.FSGOV.FDINSTADM.FFD  Expenditures
# 3664  XGDP.56.FSGOV.FDINSTADM.FFD  Expenditures
#
#                                                                       Indicator Name  \
# 0             Barro-Lee: Percentage of female population age 15-19 with no education
# 1                    Barro-Lee: Percentage of population age 15-19 with no education
# 2               Barro-Lee: Percentage of female population age 15+ with no education
# ...

# %%
upper_secondary_percentage_indicator_list = list()
for row in EdStatsSeries.iterrows():
    if re.search('percentage', row[1]['Long definition'].lower()) and \
    re.search('upper secondary', row[1]['Long definition'].lower()):
              upper_secondary_percentage_indicator_list.append(row[1]['Series Code'])

# %%
EdStatsSeries.loc[EdStatsSeries['Series Code'].isin(upper_secondary_percentage_indicator_list)]
# Out:
#                  Series Code  \
# 2313          SE.SEC.ENRR.UP
# 2314      SE.SEC.ENRR.UP.FE
# 2315       SE.SEC.ENRR.UP.MA
# 2390       SL.TLF.INTM.FE.ZS
# 2391       SL.TLF.INTM.MA.ZS
# 2392          SL.TLF.INTM.ZS
# 2647       UIS.AFR.GTCTR.3.F
# 2648       UIS.AFR.GTCTR.3.M
# 2649       UIS.AFR.GTCTR.3.T
# 2656      UIS.AFR.NTP.3.PU.F
# 2657      UIS.AFR.NTP.3.PU.M
# 2658      UIS.AFR.NTP.3.PU.T
# 2705   UIS.AFR.TATTRR.3.Pu.F
# 2706   UIS.AFR.TATTRR.3.Pu.M
# 2707   UIS.AFR.TATTRR.3.Pu.T
# 2863        UIS.EA.3.AG25T99
# 2864      UIS.EA.3.AG25T99.F
# 2865      UIS.EA.3.AG25T99.M
# 2866      UIS.EA.3T6.AG25T99
# 2867    UIS.EA.3T6.AG25T99.F
# 2868  UIS.EA.3T6.AG25T99.GPI
# 2869    UIS.EA.3T6.AG25T99.M
# 2926               UIS.FEP.3
# 2927           UIS.FEP.3.GPV
# 2928             UIS.FEP.3.V
# 2955            UIS.FOFSTP.3
# 2993               UIS.FTP.3
# 3036          UIS.GTVP.3.GPV
# 3037        UIS.GTVP.3.GPV.F
# 3038        UIS.GTVP.3.GPV.M
# 3039            UIS.GTVP.3.V
# ...

# %%
upper_secondary_percentage_indicator_list
# Out:
# ['SE.SEC.ENRR.UP',
#  'SE.SEC.ENRR.UP.FE ',
#  'SE.SEC.ENRR.UP.MA',
#  'SL.TLF.INTM.FE.ZS',
#  'SL.TLF.INTM.MA.ZS',
#  'SL.TLF.INTM.ZS',
#  'UIS.AFR.GTCTR.3.F',
#  'UIS.AFR.GTCTR.3.M',
#  'UIS.AFR.GTCTR.3.T',
#  'UIS.AFR.NTP.3.PU.F',
#  'UIS.AFR.NTP.3.PU.M',
#  'UIS.AFR.NTP.3.PU.T',
#  'UIS.AFR.TATTRR.3.Pu.F',
#  'UIS.AFR.TATTRR.3.Pu.M',
#  'UIS.AFR.TATTRR.3.Pu.T',
#  'UIS.EA.3.AG25T99',
#  'UIS.EA.3.AG25T99.F',
#  'UIS.EA.3.AG25T99.M',
#  'UIS.EA.3T6.AG25T99',
#  'UIS.EA.3T6.AG25T99.F',
#  'UIS.EA.3T6.AG25T99.GPI',
#  'UIS.EA.3T6.AG25T99.M',
#  'UIS.FEP.3',
#  'UIS.FEP.3.GPV',
#  'UIS.FEP.3.V',
#  'UIS.FOFSTP.3',
#  'UIS.FTP.3',
#  'UIS.GTVP.3.GPV',
#  'UIS.GTVP.3.GPV.F',
#  'UIS.GTVP.3.GPV.M',
#  'UIS.GTVP.3.V',
#  'UIS.GTVP.3.V.F',
#  'UIS.GTVP.3.V.M',
#  'UIS.NER.3',
#  'UIS.NER.3.F',
#  'UIS.NER.3.M',
#  'UIS.NERA.3',
#  'UIS.NERA.3.F',
#  'UIS.NERA.3.M',
#  'UIS.PRP.3',
#  'UIS.ROFST.3.CP',
#  'UIS.ROFST.3.F.CP',
#  'UIS.ROFST.3.M.CP',
#  'UIS.TRTP.3',
#  'UIS.TRTP.3.F',
# ...

# %%
for indicator in EdStatsSeries['Short definition']
    re.findall('')
# Out:
#                       Series Code         Topic  \
# 0             BAR.NOED.1519.FE.ZS    Attainment
# 1                BAR.NOED.1519.ZS    Attainment
# 2             BAR.NOED.15UP.FE.ZS    Attainment
# 3                BAR.NOED.15UP.ZS    Attainment
# 4             BAR.NOED.2024.FE.ZS    Attainment
# ...                           ...           ...
# 3660    UIS.XUNIT.USCONST.3.FSGOV  Expenditures
# 3661    UIS.XUNIT.USCONST.4.FSGOV  Expenditures
# 3662   UIS.XUNIT.USCONST.56.FSGOV  Expenditures
# 3663  XGDP.23.FSGOV.FDINSTADM.FFD  Expenditures
# 3664  XGDP.56.FSGOV.FDINSTADM.FFD  Expenditures
#
#                                                                      Indicator Name  \
# 0            Barro-Lee: Percentage of female population age 15-19 with no education
# 1                   Barro-Lee: Percentage of population age 15-19 with no education
# 2              Barro-Lee: Percentage of female population age 15+ with no education
# ...

# %% [markdown]
# SE.SEC.ENRL Total number of students enrolled at public and private secondary education institutions regardless of age.
#
# SE.SEC.ENRL.FE	Total number of female students enrolled at public and private secondary education institutions regardless of age.
#
# SE.SEC.ENRL.FE.ZS	Number of female students enrolled in all secondary education programmes expressed as a percentage of the total number of students (male and female) enrolled at the secondary education level in a given school year.
